# %%
import pandas as pd

# %%
data_1 = pd.read_csv('../project_dataset/extract - cash request - data analyst.csv')
df_cash_request = data_1.copy()
df_cash_request.sample(10)
# Out:
#           id  amount      status                     created_at  \
# 22931  20997   100.0  money_back  2020-10-14 08:26:15.386179+00
# 23255  21084   100.0  money_back  2020-10-14 13:57:41.866769+00
# 7392   17645   100.0    rejected  2020-09-24 11:50:04.688553+00
# 11869   7881   100.0  money_back  2020-07-13 22:18:56.385548+00
# 20317  22725    50.0  money_back  2020-10-21 09:45:26.125188+00
# 16500  18984    50.0  money_back  2020-10-03 06:26:55.388971+00
# 12609  21034   100.0  money_back  2020-10-14 10:36:48.078167+00
# 19976  24762   100.0  money_back  2020-10-26 16:55:22.569005+00
# 5266   12759    50.0    rejected  2020-08-17 08:42:53.708525+00
# 13988   9826    50.0  money_back  2020-07-28 05:01:07.084496+00
#
#                           updated_at  user_id                   moderated_at  \
# 22931  2020-12-18 13:14:04.623536+00  23043.0                            NaN
# 23255  2020-12-18 13:14:33.583619+00  71940.0                            NaN
# 7392   2020-09-24 12:42:42.982472+00      NaN  2020-09-24 12:42:42.974448+00
# 11869   2020-12-18 13:09:14.13329+00  32919.0  2020-07-14 12:27:38.048774+00
# 20317   2020-12-18 13:12:29.23058+00  82262.0                            NaN
# 16500  2020-12-18 13:10:55.791292+00   9269.0  2020-10-03 12:15:04.073001+00
# 12609  2020-12-18 13:09:29.242784+00      NaN                            NaN
# 19976  2020-12-18 13:12:19.199316+00  37849.0                            NaN
# 5266   2020-08-17 08:50:53.888019+00  36026.0  2020-08-17 08:50:53.883954+00
# 13988  2020-12-18 13:09:59.088151+00  17218.0  2020-07-28 10:43:32.064521+00
#
#        deleted_account_id             reimbursement_date  \
# 22931                 NaN         2020-11-02 22:00:00+00
# 23255                 NaN         2020-11-05 22:00:00+00
# 7392               6849.0  2020-10-11 11:50:04.658543+00
# 11869                 NaN     2020-08-19 22:36:19.697+00
# 20317                 NaN         2020-11-17 11:00:00+00
# 16500                 NaN         2020-10-28 22:00:00+00
# 12609             20447.0         2020-11-05 22:00:00+00
# 19976                 NaN         2020-11-09 22:00:00+00
# 5266                  NaN         2020-09-09 22:00:00+00
# 13988                 NaN         2020-08-05 22:00:00+00
#
#       cash_request_received_date                money_back_date transfer_type  \
# 22931                 2020-10-15         2020-11-05 23:00:00+00       instant
# 23255                 2020-10-16  2020-12-04 12:08:09.330303+00       instant
# 7392                         NaN                            NaN       instant
# 11869                 2020-07-16         2020-08-19 22:00:00+00       regular
# 20317                 2020-10-22  2020-11-16 18:59:23.009356+00       instant
# 16500                 2020-10-03  2020-10-29 20:06:01.475224+00       instant
# 12609                 2020-10-16  2020-11-05 20:57:09.755677+00       instant
# 19976                 2020-10-30         2020-11-12 23:00:00+00       instant
# 5266                         NaN                            NaN       regular
# 13988                 2020-07-30         2020-08-05 22:00:00+00       regular
#
#                              send_at recovery_status  \
# 22931  2020-10-14 08:26:33.988915+00             NaN
# 23255  2020-10-14 13:57:58.332573+00       completed
# 7392   2020-10-01 11:50:04.658543+00             NaN
# 11869                            NaN             NaN
# 20317  2020-10-21 09:48:49.051378+00             NaN
# 16500  2020-10-10 06:26:55.350552+00             NaN
# 12609  2020-10-14 10:36:56.135664+00             NaN
# 19976  2020-10-26 16:55:37.133851+00             NaN
# 5266   2020-08-24 08:42:53.664444+00             NaN
# 13988   2020-08-04 05:01:07.08404+00             NaN
#
#                        reco_creation               reco_last_update
# 22931                            NaN                            NaN
# 23255  2020-11-15 22:52:16.207511+00  2020-12-04 12:08:09.333888+00
# 7392                             NaN                            NaN
# 11869                            NaN                            NaN
# 20317                            NaN                            NaN
# 16500                            NaN                            NaN
# 12609                            NaN                            NaN
# 19976                            NaN                            NaN
# 5266                             NaN                            NaN
# 13988                            NaN                            NaN

# %%
data_2 = pd.read_csv('../project_dataset/extract - fees - data analyst - .csv')
df_fees = data_2.copy()
df_fees.sample(10)
# Out:
#           id  cash_request_id             type     status category  \
# 15817    252           2975.0         postpone  cancelled      NaN
# 4807   19137          21225.0         postpone  cancelled      NaN
# 780    10056          18525.0  instant_payment   accepted      NaN
# 1690    2168           9650.0         postpone   accepted      NaN
# 4646   14311          21353.0  instant_payment  confirmed      NaN
# 15833      7           1518.0         postpone  cancelled      NaN
# 11370  10183          18609.0  instant_payment   accepted      NaN
# 7764   19685          24681.0         postpone  cancelled      NaN
# 10077  10436          18824.0  instant_payment   accepted      NaN
# 6579   13018          20761.0  instant_payment  cancelled      NaN
#
#        total_amount                              reason  \
# 15817           5.0          Postpone Cash Request 2975
# 4807            5.0         Postpone Cash Request 21225
# 780             5.0  Instant Payment Cash Request 18525
# 1690            5.0          Postpone Cash Request 9650
# 4646            5.0  Instant Payment Cash Request 21353
# 15833           5.0          Postpone Cash Request 1518
# 11370           5.0  Instant Payment Cash Request 18609
# 7764            5.0         Postpone Cash Request 24681
# 10077           5.0  Instant Payment Cash Request 18824
# 6579            5.0  Instant Payment Cash Request 20761
#
#                           created_at                     updated_at  \
# 15817  2020-06-23 08:20:50.458156+00  2020-10-13 14:25:15.043375+00
# 4807   2020-10-28 13:44:49.325712+00  2020-10-28 13:44:49.325738+00
# 780      2020-09-30 10:54:29.1427+00  2020-10-13 14:25:07.911668+00
# 1690   2020-07-28 10:10:34.928198+00  2020-10-13 14:25:01.661061+00
# 4646   2020-10-17 11:03:33.239151+00  2020-10-17 11:03:33.239172+00
# 15833  2020-06-23 08:20:48.412006+00  2020-10-13 14:25:15.072076+00
# 11370  2020-10-01 07:46:54.569326+00  2020-10-13 14:25:06.877068+00
# 7764   2020-10-29 11:28:46.951946+00   2020-10-29 11:28:46.95197+00
# 10077   2020-10-02 07:08:46.67216+00  2020-10-13 14:25:04.531771+00
# 6579   2020-10-13 07:37:47.515012+00  2020-10-14 14:04:18.464966+00
#
#                              paid_at                      from_date  \
# 15817                            NaN  2020-06-26 06:53:36.627859+00
# 4807                             NaN         2020-11-08 11:00:00+00
# 780    2020-11-06 19:32:57.319566+00                            NaN
# 1690   2020-07-28 10:10:39.015078+00         2020-08-03 10:00:00+00
# 4646                             NaN                            NaN
# 15833                            NaN         2020-05-27 22:00:00+00
# 11370  2020-10-10 19:38:35.705938+00                            NaN
# 7764                             NaN         2020-11-05 11:00:00+00
# 10077  2020-11-24 11:30:34.063583+00                            NaN
# 6579                             NaN                            NaN
#
#                           to_date charge_moment
# 15817   2020-07-13 11:02:10.75+00         after
# 4807       2020-12-08 11:00:00+00        before
# 780                           NaN         after
# 1690       2020-08-04 22:00:00+00        before
# 4646                          NaN         after
# 15833  2020-06-27 03:49:38.153+00         after
# 11370                         NaN         after
# 7764       2020-11-10 11:00:00+00        before
# 10077                         NaN         after
# 6579                          NaN         after

# %% [markdown]
# The following is a copy of my code from prework for EDA:

# %%
print("Data Frame analysis for 'df_cash_request'")
print(f"Total amount of records in this data set: {df_cash_request.shape[0]} \n")
print(f"The data set contains {df_cash_request.shape[1]} columns:")
column_names_list = df_cash_request.columns.to_list()
print(f"{column_names_list}\n")

analysis_dict = {}
analysis_dict_row_template = {
    'unique_values': '',
    'unique_values_count': '',
    # data type analysis
    'data_type': '',
    'is_numerical': '',
    'is_categorical': '',
    'is_nominal': '',
    'is_ordinal': '',
    'is_continuous': '',
    'is_discrete': '',
    # discriptive stats
    'mean': '',
    'median': '',
    'mode': '',
    'standard deviation': '',
    'dispersion range': '',
    'frequency counts': '',
}

for column_name in df_cash_request:
    # DEBUG
    # print(f"Analysing data frame column: {column_name}")
    column = df_cash_request[column_name]

    # new empty entry in the dictionary with a fresh copy
    analysis_dict_row = analysis_dict_row_template.copy()

    analysis_dict_row['unique_values_count'] = len(column.unique())

    if analysis_dict_row['unique_values_count'] < 10:
        analysis_dict_row['unique_values'] = column.unique()
        print(f"Unique values in {column_name} are:\n {column.unique()}")

     # classify numbers from other
    if df_cash_request[column_name].dtype == 'int64':
        analysis_dict_row['data_type'] = 'integer'
        analysis_dict_row['is_numerical'] = True
    else:
        # point of improvement. dtype returns Object
        analysis_dict_row['data_type'] = 'not integer'
        analysis_dict_row['is_numerical'] = False

    analysis_dict_row['is_categorical'] = not analysis_dict_row['is_numerical']
    
    # only gender column contains nominal values
    analysis_dict_row['is_nominal'] = column_name == 'gender' or column_name == 'race/ethnicity'
    # all other text fields are ordinal
    analysis_dict_row['is_ordinal'] = analysis_dict_row['is_categorical'] and not analysis_dict_row['is_nominal'] 

    # all columns with scores contain continuous values
    analysis_dict_row['is_continuous'] = 'score' in column_name

    # set the other nominal as discrete if any
    analysis_dict_row['is_discrete'] = analysis_dict_row['is_nominal'] and not analysis_dict_row['is_continuous']
    

    if analysis_dict_row['is_numerical']:
        analysis_dict_row['mean'] = column.mean()
        analysis_dict_row['median'] = column.median()
        analysis_dict_row['mode'] = column.mode().tolist()
        analysis_dict_row['standard deviation'] = column.std()
        analysis_dict_row['dispersion range'] = column.max() - column.min()
    elif analysis_dict_row['is_categorical']:
        analysis_dict_row['frequency counts'] = column.value_counts().to_dict()
    else:
        raise TypeError(f"Failed to classify data of type {analysis_dict_row['data_type']}.")
    
    # store the result record in the report dictionary
    analysis_dict[column_name] = analysis_dict_row.copy()

separator = "----------------------------\n"
print(separator)

df_cash_request_report = pd.DataFrame(analysis_dict).transpose()
df_cash_request_report.head(20)
df_cash_request.to_pickle('df_cash_request.pkl')
df_cash_request_report.to_pickle('df_cash_request_report.pkl')

print("Data frame column types analysis report.")

print(separator)
print("The numerical variables are presented in columns:")
numerical_columns = df_cash_request_report[df_cash_request_report['is_numerical'] == True].index.tolist()
print(numerical_columns)
print("The categorical variables are presented in columns:")
categorical_columns = df_cash_request_report[df_cash_request_report['is_categorical'] == True].index.tolist()
print(categorical_columns)
print(f"Columns with nominal values:")
nominal_columns = df_cash_request_report[df_cash_request_report['is_nominal'] == True].index.tolist()
print(nominal_columns)
print(f"Columns with ordinal values:")
ordinal_columns = df_cash_request_report[df_cash_request_report['is_ordinal'] == True].index.tolist()
print(ordinal_columns)

print(separator)
print("Descriptive statistics for numerical data:")
column_names_list = ['mean', 'median', 'mode', 'standard deviation', 'dispersion range']
stats_for_numerical_columns = df_cash_request_report[df_cash_request_report['is_numerical'] == True][column_names_list]
print(stats_for_numerical_columns)
print(separator)

print("Descriptive statistics for categorical data:")
categorical_columns = df_cash_request_report[df_cash_request_report['is_categorical'] == True]['frequency counts']

for column, freq_dict in categorical_columns.items():
    print(f"\nFrequency counts for {column}:")
    freq_df = pd.DataFrame(list(freq_dict.items()), columns=['Category', 'Count'])
    print(freq_df)
# Out:
# Data Frame analysis for 'df_cash_request'
# Total amount of records in this data set: 23970
#
# The data set contains 16 columns:
# ['id', 'amount', 'status', 'created_at', 'updated_at', 'user_id', 'moderated_at', 'deleted_account_id', 'reimbursement_date', 'cash_request_received_date', 'money_back_date', 'transfer_type', 'send_at', 'recovery_status', 'reco_creation', 'reco_last_update']
#
# Unique values in status are:
#  ['rejected' 'money_back' 'canceled' 'active' 'direct_debit_rejected'
#  'transaction_declined' 'direct_debit_sent']
# Unique values in transfer_type are:
#  ['regular' 'instant']
# Unique values in recovery_status are:
#  [nan 'completed' 'pending' 'pending_direct_debit' 'cancelled']
# ----------------------------
#
# Data frame column types analysis report.
# ----------------------------
#
# The numerical variables are presented in columns:
# ['id']
# The categorical variables are presented in columns:
# ['amount', 'status', 'created_at', 'updated_at', 'user_id', 'moderated_at', 'deleted_account_id', 'reimbursement_date', 'cash_request_received_date', 'money_back_date', 'transfer_type', 'send_at', 'recovery_status', 'reco_creation', 'reco_last_update']
# Columns with nominal values:
# []
# Columns with ordinal values:
# ['amount', 'status', 'created_at', 'updated_at', 'user_id', 'moderated_at', 'deleted_account_id', 'reimbursement_date', 'cash_request_received_date', 'money_back_date', 'transfer_type', 'send_at', 'recovery_status', 'reco_creation', 'reco_last_update']
# ----------------------------
#
# Descriptive statistics for numerical data:
#             mean   median                                               mode  \
# id  13910.966124  14270.5  [3, 4, 5, 6, 7, 9, 10, 11, 13, 28, 34, 47, 48,...
#
#    standard deviation dispersion range
# id        7788.117214            27007
# ----------------------------
#
# Descriptive statistics for categorical data:
#
# Frequency counts for amount:
#     Category  Count
# 0      100.0  16094
# 1       50.0   5304
# 2       25.0   1276
# 3       80.0    267
# 4       60.0    190
# 5       70.0    151
# 6       20.0    132
# 7       30.0    114
# 8       40.0    100
# 9       90.0     91
# 10      10.0     57
# 11     200.0     25
# 12      95.0     21
# 13       1.0     19
# 14      75.0     18
# 15      45.0     15
# 16      55.0     14
# 17      65.0     12
# 18      99.0     12
# 19      15.0     10
# 20      85.0      9
# 21      35.0      9
# 22       5.0      6
# 23       2.0      3
# 24      98.0      2
# 25      28.0      2
# 26      22.0      2
# 27      11.0      2
# 28      49.0      1
# 29      36.0      1
# 30      54.0      1
# 31      39.0      1
# 32      97.0      1
# 33       8.0      1
# 34      86.0      1
# 35      94.0      1
# 36      67.0      1
# 37      72.0      1
# 38      31.0      1
# 39     150.0      1
# 40      24.0      1
#
# Frequency counts for status:
#                 Category  Count
# 0             money_back  16397
# 1               rejected   6568
# 2  direct_debit_rejected    831
# 3                 active     59
# 4   transaction_declined     48
# 5      direct_debit_sent     34
# 6               canceled     33
#
# Frequency counts for created_at:
#                             Category  Count
# 0      2019-12-10 19:05:21.596873+00      1
# 1      2020-09-09 11:06:31.382449+00      1
# 2      2020-10-07 05:56:54.442506+00      1
# 3      2020-09-09 12:32:29.661278+00      1
# 4      2020-09-09 11:42:31.956338+00      1
# ...                              ...    ...
# 23965   2020-04-15 09:42:07.85115+00      1
# 23966  2020-01-28 08:44:55.964552+00      1
# 23967  2020-03-26 08:46:29.025704+00      1
# 23968  2019-12-15 13:41:52.064247+00      1
# 23969  2020-10-08 14:16:52.155661+00      1
#
# [23970 rows x 2 columns]
#
# Frequency counts for updated_at:
#                             Category  Count
# 0       2019-12-11 16:47:42.40783+00      1
# 1      2020-12-18 13:10:44.348964+00      1
# 2      2020-12-18 13:10:44.448561+00      1
# 3      2020-12-18 13:10:44.439598+00      1
# 4      2020-12-18 13:10:44.429451+00      1
# ...                              ...    ...
# 23965  2020-12-22 22:08:45.274508+00      1
# 23966  2020-11-04 12:55:30.078009+00      1
# 23967  2020-11-04 12:55:58.116109+00      1
# 23968  2020-11-04 12:55:20.220846+00      1
# 23969  2021-01-05 15:45:52.645536+00      1
#
# [23970 rows x 2 columns]
#
# Frequency counts for user_id:
#        Category  Count
# 0        3377.0     19
# 1        2142.0     18
# 2       13851.0     18
# 3        2530.0     17
# 4        1159.0     17
# ...         ...    ...
# 10793    4938.0      1
# 10794   79289.0      1
# 10795   74036.0      1
# 10796   57112.0      1
# 10797   64517.0      1
#
# [10798 rows x 2 columns]
#
# Frequency counts for moderated_at:
#                             Category  Count
# 0      2019-12-11 16:47:42.405646+00      1
# 1      2020-07-10 12:43:27.336286+00      1
# 2      2020-07-08 17:55:11.030979+00      1
# 3      2020-07-02 12:53:57.219204+00      1
# 4      2020-07-17 09:13:58.632576+00      1
# ...                              ...    ...
# 16030  2020-09-16 18:07:53.044324+00      1
# 16031  2020-08-21 08:26:07.838744+00      1
# 16032  2020-09-24 14:42:24.757221+00      1
# 16033  2020-08-21 08:27:03.943839+00      1
# 16034  2020-09-19 15:37:54.670099+00      1
#
# [16035 rows x 2 columns]
#
# Frequency counts for deleted_account_id:
#       Category  Count
# 0       6334.0     19
# 1       3767.0     16
# 2      11444.0     16
# 3       4047.0     15
# 4      24168.0     13
# ...        ...    ...
# 1136    5240.0      1
# 1137    4216.0      1
# 1138    2009.0      1
# 1139    5480.0      1
# 1140   30367.0      1
#
# [1141 rows x 2 columns]
#
# Frequency counts for reimbursement_date:
#                            Category  Count
# 0            2020-11-05 22:00:00+00   1106
# 1            2020-10-05 22:00:00+00    761
# 2            2020-08-05 22:00:00+00    732
# 3            2020-09-07 22:00:00+00    554
# 4            2020-11-02 22:00:00+00    432
# ...                             ...    ...
# 4084  2020-09-11 04:52:20.778314+00      1
# 4085  2020-09-11 02:36:34.771596+00      1
# 4086  2020-09-11 06:33:06.050292+00      1
# 4087  2020-09-11 07:17:08.435449+00      1
# 4088         2021-02-05 22:00:00+00      1
#
# [4089 rows x 2 columns]
#
# Frequency counts for cash_request_received_date:
#        Category  Count
# 0    2020-10-27    716
# 1    2020-10-28    482
# 2    2020-10-30    435
# 3    2020-10-20    355
# 4    2020-11-03    345
# ..          ...    ...
# 307  2020-03-15      1
# 308  2020-01-20      1
# 309  2019-12-10      1
# 310  2020-01-23      1
# 311  2020-01-24      1
#
# [312 rows x 2 columns]
#
# Frequency counts for money_back_date:
#                             Category  Count
# 0             2020-08-04 22:00:00+00    364
# 1             2020-08-05 22:00:00+00    295
# 2             2020-07-29 22:00:00+00    244
# 3             2020-07-07 22:00:00+00    180
# 4             2020-09-01 22:00:00+00    134
# ...                              ...    ...
# 12216  2020-09-26 19:41:04.707858+00      1
# 12217  2020-09-03 18:59:16.868528+00      1
# 12218  2020-09-04 19:34:13.744825+00      1
# 12219  2020-06-30 08:44:45.520733+00      1
# 12220  2021-02-05 13:14:19.689906+00      1
#
# [12221 rows x 2 columns]
#
# Frequency counts for transfer_type:
#   Category  Count
# 0  instant  13882
# 1  regular  10088
#
# Frequency counts for send_at:
#                             Category  Count
# 0      2020-10-23 15:21:26.878525+00      1
# 1      2020-10-15 09:12:29.887167+00      1
# 2      2020-10-15 09:26:23.065397+00      1
# 3      2020-10-08 08:51:51.386371+00      1
# 4      2020-10-08 07:52:04.638453+00      1
# ...                              ...    ...
# 16636  2020-08-25 15:29:56.343502+00      1
# 16637  2020-07-29 05:57:05.332148+00      1
# 16638  2020-08-09 12:28:20.509031+00      1
# 16639  2020-10-23 10:06:36.351884+00      1
# 16640  2020-10-08 14:17:04.526139+00      1
#
# [16641 rows x 2 columns]
#
# Frequency counts for recovery_status:
#                Category  Count
# 0             completed   2468
# 1               pending    845
# 2  pending_direct_debit     16
# 3             cancelled      1
#
# Frequency counts for reco_creation:
#                            Category  Count
# 0     2020-06-12 22:27:04.837525+00      1
# 1     2020-11-11 23:01:30.183037+00      1
# 2     2020-09-22 22:34:09.112102+00      1
# 3     2020-09-22 22:23:31.824006+00      1
# 4     2020-09-22 22:41:35.956212+00      1
# ...                             ...    ...
# 3325  2020-11-15 22:44:45.510708+00      1
# 3326  2020-11-15 22:22:58.049274+00      1
# 3327  2020-11-15 22:22:21.073658+00      1
# 3328  2020-11-15 22:22:32.824054+00      1
# 3329  2020-11-12 23:20:41.928788+00      1
#
# [3330 rows x 2 columns]
#
# Frequency counts for reco_last_update:
#                            Category  Count
# 0     2020-07-06 03:36:03.030904+00      1
# 1     2020-11-11 23:01:33.548034+00      1
# 2     2020-10-03 04:45:39.909619+00      1
# 3     2020-09-22 22:23:35.480525+00      1
# 4     2020-10-03 07:48:36.457294+00      1
# ...                             ...    ...
# 3325    2021-01-05 02:19:50.1819+00      1
# 3326  2021-02-05 18:01:08.245275+00      1
# 3327    2020-11-15 22:22:24.9354+00      1
# 3328  2020-11-15 22:22:36.062846+00      1
# 3329  2020-12-01 13:26:53.815504+00      1
#
# [3330 rows x 2 columns]

# %% [markdown]
# ### TODO:
# - Add logger for debuging outputs
# - Modify the code to add tricks that Isi showed us on Week 2 and remove useless parts
# - Analyse df_fees in the same way, but specifically for that data frame
# - extract the park for saving and reading from a pickle file to use daily or on demand

# %% [markdown]
# # Data Cleanup

# %%
df_cash_request.shape
# Out:
# (23970, 16)

# %%
df_cash_request.isna().sum()
# Out:
# id                                0
# amount                            0
# status                            0
# created_at                        0
# updated_at                        0
# user_id                        2103
# moderated_at                   7935
# deleted_account_id            21866
# reimbursement_date                0
# cash_request_received_date     7681
# money_back_date                7427
# transfer_type                     0
# send_at                        7329
# recovery_status               20640
# reco_creation                 20640
# reco_last_update              20640
# dtype: int64

# %%
df_cash_request.notna().sum()
# Out:
# id                            23970
# amount                        23970
# status                        23970
# created_at                    23970
# updated_at                    23970
# user_id                       21867
# moderated_at                  16035
# deleted_account_id             2104
# reimbursement_date            23970
# cash_request_received_date    16289
# money_back_date               16543
# transfer_type                 23970
# send_at                       16641
# recovery_status                3330
# reco_creation                  3330
# reco_last_update               3330
# dtype: int64

# %%
# new Dataframe only with the customers that had recovery incidents 
# --> reduce null values from recovery_status, reco_creation, reco_last_update in the df_cash_request DataFrames
df_recovery_incidents = df_cash_request[df_cash_request["recovery_status"].notnull()]

# In this case we are using recovery_status column to create the new one (recovery_incident)
# but any of these three columns(recovery_status, reco_creation, reco_last_update) could be used for that
df_cash_request["recovery_incident"] = ~df_cash_request["reco_creation"].isna()


# Drop the columns: recovery_status, reco_creation, reco_last_update
# As they contain to many NaN values
# we want them out to clean our DataFrame
df_cash_request.drop(columns= ["recovery_status","reco_creation","reco_last_update"], inplace=True) 
df_cash_request

# Now we have two DataFrames: 
# df_cash_request with the new column recovery_incident wich tell us if there was any recovery incident (True), or not (False)
# and another DataFrame df_recovery_incidents with the information of these recovery incidents
# Out:
#           id  amount             status                     created_at  \
# 0          5   100.0           rejected  2019-12-10 19:05:21.596873+00
# 1         70   100.0           rejected   2019-12-10 19:50:12.34778+00
# 2          7   100.0           rejected   2019-12-10 19:13:35.82546+00
# 3         10    99.0           rejected  2019-12-10 19:16:10.880172+00
# 4       1594   100.0           rejected  2020-05-06 09:59:38.877376+00
# ...      ...     ...                ...                            ...
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                           updated_at  user_id                   moderated_at  \
# 0       2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1      2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2      2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# 3      2019-12-18 14:26:18.136163+00    761.0  2019-12-18 14:26:18.128407+00
# 4       2020-05-07 09:21:55.34008+00   7686.0  2020-05-07 09:21:55.320193+00
# ...                              ...      ...                            ...
# 23965  2021-02-06 20:17:49.292493+00  13681.0                            NaN
# 23966  2020-12-18 13:15:40.843946+00      NaN                            NaN
# 23967  2021-02-05 12:19:30.656816+00  82122.0                            NaN
# 23968  2021-02-05 13:14:19.707627+00  64517.0                            NaN
# 23969  2021-01-05 15:45:52.645536+00  44867.0                            NaN
#
#        deleted_account_id             reimbursement_date  \
# 0                     NaN  2020-01-09 19:05:21.596363+00
# 1                     NaN   2020-01-09 19:50:12.34778+00
# 2                     NaN  2020-01-09 19:13:35.825041+00
# 3                     NaN  2020-01-09 19:16:10.879606+00
# 4                     NaN         2020-06-05 22:00:00+00
# ...                   ...                            ...
# 23965                 NaN         2021-02-06 11:00:00+00
# 23966             30367.0         2020-11-03 22:00:00+00
# 23967                 NaN         2021-02-05 11:00:00+00
# 23968                 NaN         2021-02-05 11:00:00+00
# 23969                 NaN         2021-02-05 11:00:00+00
#
#       cash_request_received_date                money_back_date transfer_type  \
# 0                            NaN                            NaN       regular
# 1                            NaN                            NaN       regular
# 2                            NaN                            NaN       regular
# 3                            NaN                            NaN       regular
# 4                            NaN                            NaN       regular
# ...                          ...                            ...           ...
# 23965                 2020-10-13  2021-02-06 20:17:49.257521+00       instant
# 23966                 2020-10-28  2020-12-01 13:26:53.787672+00       instant
# 23967                 2020-10-21  2021-02-05 12:19:30.626289+00       instant
# 23968                 2020-10-12  2021-02-05 13:14:19.689906+00       instant
# 23969                 2020-10-10                            NaN       instant
#
#                              send_at  recovery_incident
# 0                                NaN              False
# 1                                NaN              False
# 2                                NaN              False
# 3                                NaN              False
# 4                                NaN              False
# ...                              ...                ...
# 23965  2020-10-12 13:54:24.352856+00              False
# 23966  2020-10-27 14:41:57.901946+00               True
# 23967  2020-10-20 07:58:14.171553+00              False
# 23968  2020-10-10 05:41:23.368363+00              False
# 23969  2020-10-08 14:17:04.526139+00              False
#
# [23970 rows x 14 columns]

# %%
# chechking for duplicates
print(df_cash_request.duplicated().sum())
# Out:
# 0

# %%
# Checking for empty spaces
df_cash_request.eq(" ").sum()
# Out:
# id                            0
# amount                        0
# status                        0
# created_at                    0
# updated_at                    0
# user_id                       0
# moderated_at                  0
# deleted_account_id            0
# reimbursement_date            0
# cash_request_received_date    0
# money_back_date               0
# transfer_type                 0
# send_at                       0
# recovery_incident             0
# dtype: int64

# %%
df_cash_request.columns
# Out:
# Index(['id', 'amount', 'status', 'created_at', 'updated_at', 'user_id',
#        'moderated_at', 'deleted_account_id', 'reimbursement_date',
#        'cash_request_received_date', 'money_back_date', 'transfer_type',
#        'send_at', 'recovery_incident'],
#       dtype='object')

# %%
df_cash_request[["id", "user_id", "deleted_account_id"]]
# Out:
#           id  user_id  deleted_account_id
# 0          5    804.0                 NaN
# 1         70    231.0                 NaN
# 2          7    191.0                 NaN
# 3         10    761.0                 NaN
# 4       1594   7686.0                 NaN
# ...      ...      ...                 ...
# 23965  20616  13681.0                 NaN
# 23966  25243      NaN             30367.0
# 23967  22357  82122.0                 NaN
# 23968  20256  64517.0                 NaN
# 23969  19886  44867.0                 NaN
#
# [23970 rows x 3 columns]

# %%
# Merge "user_id" and "deleted_account_id" to have no NaN values
df_cash_request["user_id_merged"] = df_cash_request["user_id"].fillna(df_cash_request["deleted_account_id"])
df_cash_request.drop(columns= ["user_id", "deleted_account_id"], inplace=True) 
df_cash_request.sample(10)
# Out:
#           id  amount      status                     created_at  \
# 2280    5037    80.0    rejected   2020-06-24 19:57:16.34484+00
# 8284    2558   100.0  money_back   2020-06-04 09:24:50.95019+00
# 15375   4080   100.0  money_back  2020-06-18 23:00:22.051317+00
# 10957   6406   100.0  money_back  2020-07-03 07:13:37.158141+00
# 7390   17659    80.0    rejected  2020-09-24 12:47:50.965161+00
# 22049  11262   100.0  money_back  2020-08-07 05:47:40.799962+00
# 7946      95   100.0  money_back  2019-12-11 14:03:07.575063+00
# 21045  25278    50.0  money_back  2020-10-27 15:51:30.884054+00
# 6293   15439   100.0    rejected  2020-09-09 19:50:24.202718+00
# 13057   9137   100.0  money_back  2020-07-20 18:36:57.561275+00
#
#                           updated_at                   moderated_at  \
# 2280   2020-06-25 12:05:10.002276+00  2020-06-25 12:05:09.997414+00
# 8284   2020-12-18 13:08:34.635803+00  2020-06-04 10:02:10.770372+00
# 15375  2020-12-18 13:10:32.828273+00  2020-06-19 11:45:57.470422+00
# 10957  2020-12-18 13:08:54.177379+00  2020-07-03 11:30:46.927894+00
# 7390   2020-09-24 14:44:08.845098+00  2020-09-24 14:44:08.837745+00
# 22049  2020-12-18 13:13:17.635388+00                            NaN
# 7946   2020-11-04 12:55:58.851879+00         2019-12-11 17:09:54+00
# 21045  2020-12-18 13:12:46.091269+00   2020-10-27 16:19:43.73972+00
# 6293   2020-09-10 08:10:30.756986+00   2020-09-10 08:10:30.74975+00
# 13057  2020-12-18 13:09:40.667486+00  2020-07-20 19:02:53.362031+00
#
#                reimbursement_date cash_request_received_date  \
# 2280       2020-07-05 22:00:00+00                        NaN
# 8284   2020-06-30 09:25:21.834+00                 2020-06-05
# 15375      2020-07-13 22:00:00+00                 2020-06-23
# 10957    2020-09-20 04:09:45.2+00                 2020-07-07
# 7390       2020-10-10 23:51:00+00                        NaN
# 22049      2020-09-02 22:00:00+00                 2020-08-14
# 7946       2020-03-09 23:00:00+00                 2019-12-12
# 21045      2020-11-09 23:51:00+00                 2020-10-28
# 6293       2020-09-30 22:00:00+00                        NaN
# 13057      2020-08-03 22:00:00+00                 2020-07-21
#
#                      money_back_date transfer_type  \
# 2280                             NaN       regular
# 8284    2020-07-02 19:21:27.24879+00       regular
# 15375  2020-09-15 09:27:40.198979+00       regular
# 10957  2020-09-20 19:42:20.239506+00       regular
# 7390                             NaN       instant
# 22049         2020-09-02 22:00:00+00       regular
# 7946   2020-04-16 21:16:02.602862+00       regular
# 21045  2020-11-07 06:47:59.721314+00       instant
# 6293                             NaN       instant
# 13057         2020-08-04 22:00:00+00       regular
#
#                              send_at  recovery_incident  user_id_merged
# 2280                             NaN              False         20160.0
# 8284                             NaN              False         12293.0
# 15375                            NaN               True          6212.0
# 10957                            NaN              False          4925.0
# 7390   2020-10-01 12:47:50.940362+00              False         48277.0
# 22049  2020-08-14 05:47:40.799552+00              False         10955.0
# 7946                             NaN               True          1204.0
# 21045  2020-10-27 15:51:39.900509+00              False         77490.0
# 6293   2020-09-16 19:50:24.153392+00              False          5125.0
# 13057  2020-07-27 18:36:57.560902+00              False         13077.0

# %%
# We keep everything else with NaN
df_cash_request.isna().sum()
# Out:
# id                               0
# amount                           0
# status                           0
# created_at                       0
# updated_at                       0
# moderated_at                  7935
# reimbursement_date               0
# cash_request_received_date    7681
# money_back_date               7427
# transfer_type                    0
# send_at                       7329
# recovery_incident                0
# user_id_merged                   0
# dtype: int64

# %%
df_fees.shape
# Out:
# (21061, 13)

# %%
df_fees.notna().sum()
# Out:
# id                 21061
# cash_request_id    21057
# type               21061
# status             21061
# category            2196
# total_amount       21061
# reason             21061
# created_at         21061
# updated_at         21061
# paid_at            15531
# from_date           7766
# to_date             7766
# charge_moment      21061
# dtype: int64

# %%
df_fees.isna().sum()
# Out:
# id                     0
# cash_request_id        4
# type                   0
# status                 0
# category           18865
# total_amount           0
# reason                 0
# created_at             0
# updated_at             0
# paid_at             5530
# from_date          13295
# to_date            13295
# charge_moment          0
# dtype: int64

# %%
#  save information about cases with pospone fees 
# to a new data frame `df_postpone_fees`
df_postpone_fees = df_fees[df_fees["from_date"].notnull()]
df_postpone_fees
# Out:
#           id  cash_request_id      type     status category  total_amount  \
# 9      15431          22106.0  postpone  cancelled      NaN           5.0
# 11     15434          21897.0  postpone   accepted      NaN           5.0
# 12     20199          25490.0  postpone  cancelled      NaN           5.0
# 17     13949          19876.0  postpone   accepted      NaN           5.0
# 19     19761          24564.0  postpone  cancelled      NaN           5.0
# ...      ...              ...       ...        ...      ...           ...
# 20593    411           3891.0  postpone   accepted      NaN           5.0
# 20597   1022           2717.0  postpone   accepted      NaN           5.0
# 20605    681           3716.0  postpone   accepted      NaN           5.0
# 20607   4561          10801.0  postpone   accepted      NaN           5.0
# 21013    832           4112.0  postpone  cancelled      NaN           5.0
#
#                             reason                     created_at  \
# 9      Postpone Cash Request 22106  2020-10-21 08:48:50.696961+00
# 11     Postpone Cash Request 21897  2020-10-21 09:00:21.619473+00
# 12     Postpone Cash Request 25490   2020-10-30 16:51:49.45659+00
# 17     Postpone Cash Request 19876   2020-10-16 08:34:39.39839+00
# 19     Postpone Cash Request 24564  2020-10-29 14:00:30.956061+00
# ...                            ...                            ...
# 20593   Postpone Cash Request 3891  2020-06-22 08:24:47.439636+00
# 20597   Postpone Cash Request 2717   2020-07-04 10:05:48.68153+00
# 20605   Postpone Cash Request 3716  2020-06-26 15:13:10.276716+00
# 20607  Postpone Cash Request 10801  2020-08-21 11:28:54.470364+00
# 21013   Postpone Cash Request 4112   2020-06-30 12:23:06.52225+00
#
#                           updated_at                        paid_at  \
# 9      2020-10-21 08:48:50.696991+00                            NaN
# 11     2020-10-21 09:00:21.619504+00  2020-10-21 09:00:25.398771+00
# 12     2020-10-30 16:51:49.456616+00                            NaN
# 17     2020-10-16 08:34:39.398412+00  2020-10-16 08:34:43.529531+00
# 19     2020-10-29 14:00:30.956085+00                            NaN
# ...                              ...                            ...
# 20593  2021-01-20 14:46:09.980392+00                            NaN
# 20597  2021-01-20 16:59:23.745182+00         2020-07-04 10:05:52+00
# 20605  2021-01-21 15:47:52.053382+00         2020-06-26 15:13:45+00
# 20607  2021-01-21 16:54:46.995586+00         2020-08-21 11:29:00+00
# 21013  2021-02-08 16:09:22.195973+00         2020-06-30 12:23:06+00
#
#                         from_date                 to_date charge_moment
# 9          2020-11-04 22:00:00+00  2020-11-05 11:00:00+00        before
# 11         2020-10-26 22:00:00+00  2020-10-30 23:00:00+00        before
# 12         2020-11-06 22:00:00+00  2020-11-12 11:00:00+00        before
# 17     2020-10-23 13:25:59.902+00  2020-11-03 23:00:00+00        before
# 19         2020-10-29 23:00:00+00  2020-10-30 23:00:00+00        before
# ...                           ...                     ...           ...
# 20593      2020-07-03 22:00:00+00  2020-07-18 22:00:00+00        before
# 20597      2020-07-07 22:00:00+00  2020-08-04 22:00:00+00        before
# 20605      2020-07-20 22:00:00+00  2020-08-04 22:00:00+00        before
# 20607      2020-09-08 10:00:00+00  2020-10-07 10:00:00+00        before
# 21013      2020-07-06 22:00:00+00  2020-08-06 12:22:58+00        before
#
# [7766 rows x 13 columns]

# %%
# drop columns "from_date","to_date" because of lots of NaN
# keep the information that those were postpone fees cases
df_fees["postpone_fees"] = df_fees["from_date"].notna()
df_fees.drop(columns= ["from_date","to_date"], inplace=True) 
df_fees
# Out:
#           id  cash_request_id             type    status  \
# 0       6537          14941.0  instant_payment  rejected
# 1       6961          11714.0         incident  accepted
# 2      16296          23371.0  instant_payment  accepted
# 3      20775          26772.0  instant_payment  accepted
# 4      11242          19350.0  instant_payment  accepted
# ...      ...              ...              ...       ...
# 21056  12372          20262.0  instant_payment  rejected
# 21057  20768          26764.0  instant_payment  rejected
# 21058  18779          25331.0  instant_payment  rejected
# 21059  16542          23628.0  instant_payment  rejected
# 21060  13301          20982.0  instant_payment  accepted
#
#                     category  total_amount  \
# 0                        NaN           5.0
# 1      rejected_direct_debit           5.0
# 2                        NaN           5.0
# 3                        NaN           5.0
# 4                        NaN           5.0
# ...                      ...           ...
# 21056                    NaN           5.0
# 21057                    NaN           5.0
# 21058                    NaN           5.0
# 21059                    NaN           5.0
# 21060                    NaN           5.0
#
#                                    reason                     created_at  \
# 0      Instant Payment Cash Request 14941   2020-09-07 10:47:27.42315+00
# 1                   rejected direct debit  2020-09-09 20:51:17.998653+00
# 2      Instant Payment Cash Request 23371  2020-10-23 10:10:58.352972+00
# 3      Instant Payment Cash Request 26772  2020-10-31 15:46:53.643958+00
# 4      Instant Payment Cash Request 19350  2020-10-06 08:20:17.170432+00
# ...                                   ...                            ...
# 21056  Instant Payment Cash Request 20262  2020-10-10 06:42:22.822743+00
# 21057  Instant Payment Cash Request 26764  2020-10-31 15:24:18.680694+00
# 21058  Instant Payment Cash Request 25331  2020-10-27 17:28:51.749177+00
# 21059  Instant Payment Cash Request 23628  2020-10-23 16:27:52.047457+00
# 21060  Instant Payment Cash Request 20982  2020-10-14 07:12:43.958192+00
#
#                           updated_at                        paid_at  \
# 0      2020-10-13 14:25:09.396112+00   2020-12-17 14:50:07.47011+00
# 1      2020-10-13 14:25:15.537063+00   2020-12-08 17:13:10.45908+00
# 2      2020-10-23 10:10:58.352994+00   2020-11-04 19:34:37.43291+00
# 3      2020-10-31 15:46:53.643982+00  2020-11-19 05:09:22.500223+00
# 4      2020-10-13 14:25:03.267983+00  2020-11-02 14:45:20.355598+00
# ...                              ...                            ...
# 21056   2020-10-13 14:25:04.18049+00  2020-11-17 05:14:00.080854+00
# 21057  2020-10-31 15:24:18.680715+00  2020-12-16 07:10:54.697639+00
# 21058    2020-10-27 17:28:51.7492+00  2020-11-18 04:35:42.915511+00
# 21059  2020-10-23 16:27:52.047486+00  2020-12-18 05:18:01.465317+00
# 21060  2020-10-14 07:12:43.958219+00   2021-02-12 13:02:46.95022+00
#
#       charge_moment  postpone_fees
# 0             after          False
# 1             after          False
# 2             after          False
# 3             after          False
# 4             after          False
# ...             ...            ...
# 21056         after          False
# 21057         after          False
# 21058         after          False
# 21059         after          False
# 21060         after          False
#
# [21061 rows x 12 columns]

# %%
# category column describes the reason of the incident fee.
# save this informstion separately, keep a flag that thewre was an incident
df_fees_incident = df_fees[df_fees["category"].notnull()]
df_fees_incident
# Out:
#           id  cash_request_id      type    status                category  \
# 1       6961          11714.0  incident  accepted   rejected_direct_debit
# 7      14187          14839.0  incident  accepted   rejected_direct_debit
# 15     14420          17963.0  incident  accepted   rejected_direct_debit
# 27     14433          10287.0  incident  rejected   rejected_direct_debit
# 40     14188          15989.0  incident  accepted   rejected_direct_debit
# ...      ...              ...       ...       ...                     ...
# 21044   3491           8952.0  incident  rejected   rejected_direct_debit
# 21045   7166           8952.0  incident  rejected  month_delay_on_payment
# 21046  12566           8952.0  incident  rejected  month_delay_on_payment
# 21047  13537          14289.0  incident  rejected   rejected_direct_debit
# 21051  20897          17900.0  incident  rejected   rejected_direct_debit
#
#        total_amount                           reason  \
# 1               5.0            rejected direct debit
# 7               5.0            rejected direct debit
# 15              5.0            rejected direct debit
# 27              5.0            rejected direct debit
# 40              5.0            rejected direct debit
# ...             ...                              ...
# 21044           5.0            rejected direct debit
# 21045           5.0  month delay on payment - 9/2020
# 21046           5.0  month delay on payment - 9/2020
# 21047           5.0            rejected direct debit
# 21051           5.0            rejected direct debit
#
#                           created_at                     updated_at  \
# 1      2020-09-09 20:51:17.998653+00  2020-10-13 14:25:15.537063+00
# 7      2020-10-16 23:48:50.655967+00  2020-10-16 23:48:50.655988+00
# 15     2020-10-17 22:18:53.924407+00  2020-10-17 22:18:53.924429+00
# 27     2020-10-17 22:19:48.806283+00  2020-10-17 22:19:48.806303+00
# 40      2020-10-16 23:48:52.16855+00  2020-10-16 23:48:52.168578+00
# ...                              ...                            ...
# 21044  2020-08-11 23:00:44.214576+00  2020-10-13 14:25:02.938088+00
# 21045  2020-09-11 01:37:43.458593+00  2020-10-13 14:25:02.546591+00
# 21046  2020-10-10 23:26:30.997317+00  2020-10-13 14:25:18.627143+00
# 21047  2020-10-14 22:35:49.950325+00  2020-10-14 22:35:49.950347+00
# 21051  2020-10-31 22:23:35.750458+00  2020-10-31 22:23:35.750475+00
#
#                              paid_at charge_moment  postpone_fees
# 1       2020-12-08 17:13:10.45908+00         after          False
# 7      2020-11-05 14:15:36.600041+00         after          False
# 15      2020-10-17 22:19:00.10911+00         after          False
# 27     2020-12-17 14:33:35.516056+00         after          False
# 40     2020-11-16 13:33:09.113667+00         after          False
# ...                              ...           ...            ...
# 21044  2020-10-08 07:24:45.091469+00         after          False
# 21045  2020-10-08 07:24:44.561304+00         after          False
# 21046                            NaN         after          False
# 21047                            NaN         after          False
# 21051                            NaN         after          False
#
# [2196 rows x 12 columns]

# %%
df_fees["is_incident"] = df_fees["category"].notna()
df_fees.drop(columns= ["category"], inplace=True) 
df_fees
# Out:
#           id  cash_request_id             type    status  total_amount  \
# 0       6537          14941.0  instant_payment  rejected           5.0
# 1       6961          11714.0         incident  accepted           5.0
# 2      16296          23371.0  instant_payment  accepted           5.0
# 3      20775          26772.0  instant_payment  accepted           5.0
# 4      11242          19350.0  instant_payment  accepted           5.0
# ...      ...              ...              ...       ...           ...
# 21056  12372          20262.0  instant_payment  rejected           5.0
# 21057  20768          26764.0  instant_payment  rejected           5.0
# 21058  18779          25331.0  instant_payment  rejected           5.0
# 21059  16542          23628.0  instant_payment  rejected           5.0
# 21060  13301          20982.0  instant_payment  accepted           5.0
#
#                                    reason                     created_at  \
# 0      Instant Payment Cash Request 14941   2020-09-07 10:47:27.42315+00
# 1                   rejected direct debit  2020-09-09 20:51:17.998653+00
# 2      Instant Payment Cash Request 23371  2020-10-23 10:10:58.352972+00
# 3      Instant Payment Cash Request 26772  2020-10-31 15:46:53.643958+00
# 4      Instant Payment Cash Request 19350  2020-10-06 08:20:17.170432+00
# ...                                   ...                            ...
# 21056  Instant Payment Cash Request 20262  2020-10-10 06:42:22.822743+00
# 21057  Instant Payment Cash Request 26764  2020-10-31 15:24:18.680694+00
# 21058  Instant Payment Cash Request 25331  2020-10-27 17:28:51.749177+00
# 21059  Instant Payment Cash Request 23628  2020-10-23 16:27:52.047457+00
# 21060  Instant Payment Cash Request 20982  2020-10-14 07:12:43.958192+00
#
#                           updated_at                        paid_at  \
# 0      2020-10-13 14:25:09.396112+00   2020-12-17 14:50:07.47011+00
# 1      2020-10-13 14:25:15.537063+00   2020-12-08 17:13:10.45908+00
# 2      2020-10-23 10:10:58.352994+00   2020-11-04 19:34:37.43291+00
# 3      2020-10-31 15:46:53.643982+00  2020-11-19 05:09:22.500223+00
# 4      2020-10-13 14:25:03.267983+00  2020-11-02 14:45:20.355598+00
# ...                              ...                            ...
# 21056   2020-10-13 14:25:04.18049+00  2020-11-17 05:14:00.080854+00
# 21057  2020-10-31 15:24:18.680715+00  2020-12-16 07:10:54.697639+00
# 21058    2020-10-27 17:28:51.7492+00  2020-11-18 04:35:42.915511+00
# 21059  2020-10-23 16:27:52.047486+00  2020-12-18 05:18:01.465317+00
# 21060  2020-10-14 07:12:43.958219+00   2021-02-12 13:02:46.95022+00
#
#       charge_moment  postpone_fees  is_incident
# 0             after          False        False
# 1             after          False         True
# 2             after          False        False
# 3             after          False        False
# 4             after          False        False
# ...             ...            ...          ...
# 21056         after          False        False
# 21057         after          False        False
# 21058         after          False        False
# 21059         after          False        False
# 21060         after          False        False
#
# [21061 rows x 12 columns]

# %%
# chechking for duplicates
print(df_fees.duplicated().sum())
# Out:
# 0

# %%
# Checking for empty spaces
df_fees.eq(" ").sum()
# Out:
# id                 0
# cash_request_id    0
# type               0
# status             0
# total_amount       0
# reason             0
# created_at         0
# updated_at         0
# paid_at            0
# charge_moment      0
# postpone_fees      0
# is_incident        0
# dtype: int64

# %% [markdown]
# # Identifying cohorts

# %%
# df_cash_request["created_at"]

# %%
df_cash_request.shape
# Out:
# (23970, 13)

# %%
len(df_cash_request["created_at"].unique())
# Out:
# 23970

# %%
df_cash_request["created_at"].min()
# Out:
# '2019-11-19 13:57:53.511561+00'

# %%
df_cash_request["created_at"].max()
# Out:
# '2020-11-01 23:42:30.847066+00'

# %%
# test time stamp convertion methods
sample_date = '2020-11-01 23:42:30.847066+00'
converted = pd.to_datetime(sample_date)
print(converted)
print(type(converted))
date = converted.date()  # Extracts only the date part
print(date)
yy_mm = converted.strftime('%Y-%m')
print(yy_mm)
# Out:
# 2020-11-01 23:42:30.847066+00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2020-11-01
# 2020-11

# %%
# convert all values to datetime format in one column
df_cash_request["created_at"] = pd.to_datetime(df_cash_request["created_at"])
df_cash_request["created_at"].sample(10)
# Out:
# 2613    2020-07-28 11:12:55.075439+00:00
# 8010    2019-12-21 12:26:41.751352+00:00
# 14565   2020-08-15 16:43:20.797342+00:00
# 7056    2020-04-28 18:31:09.414595+00:00
# 7654    2020-09-28 13:13:04.747704+00:00
# 8513    2020-10-14 15:18:30.140539+00:00
# 20202   2020-10-20 14:21:44.867537+00:00
# 16928   2020-10-24 11:02:53.006598+00:00
# 23642   2020-10-22 16:38:17.035130+00:00
# 3828    2020-05-29 11:51:07.984110+00:00
# Name: created_at, dtype: datetime64[ns, UTC]

# %%
# new column with yy_mm from created_at
df_cash_request["month_created"] = df_cash_request["created_at"].dt.strftime('%Y-%m')
df_cash_request["month_created"].sample(10)
# Out:
# 9580     2020-07
# 15829    2020-09
# 1687     2020-08
# 10570    2020-06
# 5538     2020-08
# 18183    2020-09
# 4092     2020-10
# 5375     2020-06
# 17753    2020-09
# 3635     2020-06
# Name: month_created, dtype: object

# %%
print(df_cash_request["month_created"].nunique())
print(df_cash_request["month_created"].max())
print(df_cash_request["month_created"].min())
print(df_cash_request["month_created"].mode())
# Out:
# 13
# 2020-11
# 2019-11
# 0    2020-10
# Name: month_created, dtype: object

# %%
df_cash_request.columns
# Out:
# Index(['id', 'amount', 'status', 'created_at', 'updated_at', 'moderated_at',
#        'reimbursement_date', 'cash_request_received_date', 'money_back_date',
#        'transfer_type', 'send_at', 'recovery_incident', 'user_id_merged',
#        'month_created'],
#       dtype='object')

# %%
# todo: rename id column to cash_request_id
df_cash_request.rename(columns={"id": "cash_request_id"}, inplace=True)
df_cash_request.head(1)
# Out:
#    cash_request_id  amount    status                       created_at  \
# 0                5   100.0  rejected 2019-12-10 19:05:21.596873+00:00
#
#                      updated_at                   moderated_at  \
# 0  2019-12-11 16:47:42.40783+00  2019-12-11 16:47:42.405646+00
#
#               reimbursement_date cash_request_received_date money_back_date  \
# 0  2020-01-09 19:05:21.596363+00                        NaN             NaN
#
#   transfer_type send_at  recovery_incident  user_id_merged month_created
# 0       regular     NaN              False           804.0       2019-12

# %%
# see amount of user for each month
df_cash_request[["cash_request_id", "month_created"]].groupby("month_created").count()
# Out:
#                cash_request_id
# month_created
# 2019-11                      1
# 2019-12                    289
# 2020-01                    223
# 2020-02                    184
# 2020-03                    244
# 2020-04                    473
# 2020-05                    837
# 2020-06                   2615
# 2020-07                   3601
# 2020-08                   3417
# 2020-09                   4221
# 2020-10                   7725
# 2020-11                    140

# %%
# drop the fist month records because there was only one cash request in the opening month
df_cash_request[df_cash_request["month_created"] == '2019-11']
# Out:
#       cash_request_id  amount    status                       created_at  \
# 7920                3     1.0  canceled 2019-11-19 13:57:53.511561+00:00
#
#                          updated_at            moderated_at  \
# 7920  2020-12-14 10:25:57.710844+00  2019-11-20 12:16:50+00
#
#           reimbursement_date cash_request_received_date money_back_date  \
# 7920  2019-12-05 23:00:00+00                        NaN             NaN
#
#      transfer_type send_at  recovery_incident  user_id_merged month_created
# 7920       regular     NaN              False            47.0       2019-11

# %%
index_to_drop = df_cash_request[df_cash_request["month_created"] == '2019-11'].index

# %%
df_cash_request.drop(index_to_drop, inplace=True)
df_cash_request.sample(3)
# Out:
#        cash_request_id  amount      status                       created_at  \
# 21279            25683   100.0  money_back 2020-10-28 16:01:27.768101+00:00
# 16320            15781    50.0  money_back 2020-09-12 05:28:07.826070+00:00
# 21695            23695    25.0  money_back 2020-10-23 17:15:17.658479+00:00
#
#                           updated_at                   moderated_at  \
# 21279  2020-12-18 13:12:51.452273+00                            NaN
# 16320  2020-12-18 13:10:50.431918+00  2020-09-12 08:54:50.482011+00
# 21695  2020-12-18 13:13:02.985431+00                            NaN
#
#            reimbursement_date cash_request_received_date  \
# 21279  2020-11-05 22:00:00+00                 2020-10-30
# 16320  2020-10-05 22:00:00+00                 2020-09-22
# 21695  2020-11-07 11:00:00+00                        NaN
#
#                      money_back_date transfer_type  \
# 21279  2020-11-06 21:33:18.025924+00       instant
# 16320  2020-10-06 19:41:14.409207+00       regular
# 21695  2020-11-07 19:55:45.035773+00       instant
#
#                              send_at  recovery_incident  user_id_merged  \
# 21279  2020-10-28 16:01:36.174465+00              False         95484.0
# 16320  2020-09-19 05:28:07.780327+00              False         27086.0
# 21695  2020-10-23 17:15:29.225761+00              False         69292.0
#
#       month_created
# 21279       2020-10
# 16320       2020-09
# 21695       2020-10

# %%
df_cash_request[["cash_request_id", "month_created"]].groupby("month_created").count()
# Out:
#                cash_request_id
# month_created
# 2019-12                    289
# 2020-01                    223
# 2020-02                    184
# 2020-03                    244
# 2020-04                    473
# 2020-05                    837
# 2020-06                   2615
# 2020-07                   3601
# 2020-08                   3417
# 2020-09                   4221
# 2020-10                   7725
# 2020-11                    140

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# sort by date created
df_cash_request_hist = df_cash_request.sort_values("created_at")
df_cash_request_hist.head(5)
# Out:
#        cash_request_id  amount                 status  \
# 7260                 4   100.0             money_back
# 0                    5   100.0               rejected
# 10030                6   100.0  direct_debit_rejected
# 2                    7   100.0               rejected
# 7824                 9   100.0             money_back
#
#                             created_at                     updated_at  \
# 7260  2019-12-09 14:47:35.190714+00:00  2020-11-04 12:54:52.120014+00
# 0     2019-12-10 19:05:21.596873+00:00   2019-12-11 16:47:42.40783+00
# 10030 2019-12-10 19:05:48.921042+00:00  2020-12-18 22:47:47.993817+00
# 2     2019-12-10 19:13:35.825460+00:00  2019-12-11 09:46:59.779773+00
# 7824  2019-12-10 19:14:41.668754+00:00  2020-11-04 12:55:30.918436+00
#
#                         moderated_at             reimbursement_date  \
# 7260          2019-12-09 14:58:28+00         2019-12-16 23:00:00+00
# 0      2019-12-11 16:47:42.405646+00  2020-01-09 19:05:21.596363+00
# 10030         2019-12-11 09:40:33+00         2020-02-05 23:00:00+00
# 2      2019-12-11 09:46:59.777728+00  2020-01-09 19:13:35.825041+00
# 7824          2019-12-11 09:50:51+00         2020-01-08 23:00:00+00
#
#       cash_request_received_date         money_back_date transfer_type  \
# 7260                         NaN                     NaN       regular
# 0                            NaN                     NaN       regular
# 10030                 2019-12-11                     NaN       regular
# 2                            NaN                     NaN       regular
# 7824                  2019-12-11  2020-05-12 11:05:30+00       regular
#
#       send_at  recovery_incident  user_id_merged month_created
# 7260      NaN              False          1309.0       2019-12
# 0         NaN              False           804.0       2019-12
# 10030     NaN               True           812.0       2019-12
# 2         NaN              False           191.0       2019-12
# 7824      NaN               True           430.0       2019-12

# %%
print("Cash requests by month")

plt.figure()
sns.histplot(x="month_created", data=df_cash_request_hist, discrete=True)
plt.title(f'Cash requests by month')
plt.xticks(rotation=45)
plt.show()
# Out:
# Cash requests by month

# %% [markdown]
# We observe high Kurtis and Negative Skewing.

# %%
df_cash_request.loc[df_cash_request["month_created"] == "2020-11", "created_at"].head(1)
# Out:
# 6702   2020-11-01 06:30:52.379614+00:00
# Name: created_at, dtype: datetime64[ns, UTC]

# %%
df_cash_request.loc[df_cash_request["month_created"] == "2020-11", "created_at"].tail(1)
# Out:
# 23962   2020-11-01 19:08:24.111371+00:00
# Name: created_at, dtype: datetime64[ns, UTC]

# %%
# Creating the cohorts
min_date = df_cash_request["month_created"].min()
max_date = df_cash_request["month_created"].max()

print(min_date)
print(max_date)

bins = [min_date , '2020-05', max_date]
labels = ['Cohorts-1', 'Cohorts-2']
df_cash_request["cohort"] = pd.cut(df_cash_request["month_created"], bins =bins,labels=labels, include_lowest = True)

df_cash_request.head(20)
# Out:
# 2019-12
# 2020-11
#     cash_request_id  amount      status                       created_at  \
# 0                 5   100.0    rejected 2019-12-10 19:05:21.596873+00:00
# 1                70   100.0    rejected 2019-12-10 19:50:12.347780+00:00
# 2                 7   100.0    rejected 2019-12-10 19:13:35.825460+00:00
# 3                10    99.0    rejected 2019-12-10 19:16:10.880172+00:00
# 4              1594   100.0    rejected 2020-05-06 09:59:38.877376+00:00
# 5              2145   100.0  money_back 2020-05-23 20:58:55.129432+00:00
# 6              3512   100.0    rejected 2020-06-16 17:07:38.452652+00:00
# 7               654   100.0    rejected 2020-02-10 01:11:53.808270+00:00
# 8              5672   100.0    canceled 2020-06-28 12:06:33.712840+00:00
# 9                71    90.0    rejected 2019-12-10 19:51:23.911206+00:00
# 10              648     1.0    rejected 2020-02-08 19:20:44.627662+00:00
# 11             1794   100.0  money_back 2020-05-14 21:11:47.393326+00:00
# 12              655     1.0    rejected 2020-02-10 13:22:10.013736+00:00
# 13             2122   100.0  money_back 2020-05-22 12:47:42.741369+00:00
# 14              741   100.0    rejected 2020-02-27 06:02:27.394185+00:00
# 15               83   100.0    rejected 2019-12-11 07:09:44.687256+00:00
# 16              690   100.0    rejected 2020-02-17 18:22:25.824497+00:00
# 17              756    70.0    rejected 2020-02-28 10:13:18.421583+00:00
# 18             1073   100.0    rejected 2020-04-08 02:21:48.854449+00:00
# 19              545   100.0    rejected 2020-01-29 13:53:03.343598+00:00
#
#                        updated_at                   moderated_at  \
# 0    2019-12-11 16:47:42.40783+00  2019-12-11 16:47:42.405646+00
# 1   2019-12-11 14:24:22.900054+00  2019-12-11 14:24:22.897988+00
# 2   2019-12-11 09:46:59.779773+00  2019-12-11 09:46:59.777728+00
# 3   2019-12-18 14:26:18.136163+00  2019-12-18 14:26:18.128407+00
# 4    2020-05-07 09:21:55.34008+00  2020-05-07 09:21:55.320193+00
# 5   2020-07-06 03:36:03.023911+00   2020-05-24 12:40:33.05491+00
# 6   2020-06-17 10:21:21.364746+00  2020-06-17 10:21:21.360742+00
# 7   2020-02-10 11:53:32.104131+00  2020-02-10 09:11:21.350695+00
# 8   2020-06-28 12:06:33.712853+00                            NaN
# 9   2019-12-12 15:06:11.192888+00  2019-12-12 15:06:11.190299+00
# 10  2020-02-09 13:59:26.784459+00  2020-02-09 13:59:26.779954+00
# 11  2020-06-03 05:11:35.312872+00  2020-05-15 09:11:17.272832+00
# 12  2020-02-10 15:36:10.665778+00  2020-02-10 15:36:10.661861+00
# 13  2020-06-13 06:36:34.188372+00  2020-05-23 14:29:15.376466+00
# 14  2020-02-27 07:44:25.478286+00  2020-02-27 07:44:25.474845+00
# 15  2019-12-18 15:07:44.215656+00  2019-12-18 15:07:44.208674+00
# 16  2020-02-17 19:16:55.655247+00  2020-02-17 19:16:55.652115+00
# 17   2020-02-28 14:12:15.07666+00  2020-02-28 14:12:15.073471+00
# 18  2020-04-08 09:41:16.026093+00  2020-04-08 09:41:16.022533+00
# 19  2020-02-08 06:21:16.156719+00  2020-01-29 14:39:11.563872+00
#
#                reimbursement_date cash_request_received_date  \
# 0   2020-01-09 19:05:21.596363+00                        NaN
# 1    2020-01-09 19:50:12.34778+00                        NaN
# 2   2020-01-09 19:13:35.825041+00                        NaN
# 3   2020-01-09 19:16:10.879606+00                        NaN
# 4          2020-06-05 22:00:00+00                        NaN
# 5          2020-06-06 22:00:00+00                 2020-05-26
# 6          2020-07-11 23:51:00+00                        NaN
# 7    2020-03-11 01:11:53.80793+00                        NaN
# 8          2020-07-07 22:00:00+00                        NaN
# 9   2019-12-17 19:51:23.910748+00                        NaN
# 10  2020-03-09 19:20:44.627255+00                        NaN
# 11     2020-05-29 21:11:46.695+00                 2020-05-17
# 12  2020-02-17 13:22:10.013228+00                        NaN
# 13         2020-06-15 22:00:00+00                 2020-05-27
# 14  2020-03-05 06:02:27.393674+00                        NaN
# 15  2020-01-10 07:09:44.686718+00                        NaN
# 16  2020-03-18 18:22:25.824099+00                        NaN
# 17         2020-03-07 23:00:00+00                        NaN
# 18         2020-04-30 23:00:00+00                        NaN
# 19  2020-02-28 13:53:03.343216+00                        NaN
#
#                   money_back_date transfer_type send_at  recovery_incident  \
# 0                             NaN       regular     NaN              False
# 1                             NaN       regular     NaN              False
# 2                             NaN       regular     NaN              False
# 3                             NaN       regular     NaN              False
# 4                             NaN       regular     NaN              False
# 5   2020-07-06 03:36:03.023521+00       regular     NaN               True
# 6                             NaN       regular     NaN              False
# 7                             NaN       regular     NaN              False
# 8                             NaN       regular     NaN              False
# 9                             NaN       regular     NaN              False
# 10                            NaN       regular     NaN              False
# 11  2020-06-03 05:11:35.312616+00       regular     NaN               True
# 12                            NaN       regular     NaN              False
# 13  2020-06-13 06:36:34.188042+00       regular     NaN              False
# 14                            NaN       regular     NaN              False
# 15                            NaN       regular     NaN              False
# 16                            NaN       regular     NaN              False
# 17                            NaN       regular     NaN              False
# 18                            NaN       regular     NaN              False
# 19                            NaN       regular     NaN              False
#
#     user_id_merged month_created     cohort
# 0            804.0       2019-12  Cohorts-1
# 1            231.0       2019-12  Cohorts-1
# 2            191.0       2019-12  Cohorts-1
# 3            761.0       2019-12  Cohorts-1
# 4           7686.0       2020-05  Cohorts-1
# 5           9489.0       2020-05  Cohorts-1
# 6          14631.0       2020-06  Cohorts-2
# 7            309.0       2020-02  Cohorts-1
# 8           2499.0       2020-06  Cohorts-2
# 9            897.0       2019-12  Cohorts-1
# 10          2908.0       2020-02  Cohorts-1
# 11           778.0       2020-05  Cohorts-1
# 12           163.0       2020-02  Cohorts-1
# 13          8218.0       2020-05  Cohorts-1
# 14          1547.0       2020-02  Cohorts-1
# 15          1248.0       2019-12  Cohorts-1
# 16           939.0       2020-02  Cohorts-1
# 17           821.0       2020-02  Cohorts-1
# 18          2867.0       2020-04  Cohorts-1
# 19           304.0       2020-01  Cohorts-1

# %% [markdown]
# # Revenue Generated by the Cohort

# %%
print("NaNs id in df_fees",df_fees["id"].isnull().sum())
print("NaNs cash_request_id in df_fees",df_fees["cash_request_id"].isnull().sum())
print("NaNs cash_request id in df_cash_request", df_cash_request["cash_request_id"].isnull().sum())

# create column "cohort" in df_fees and map cohort values from df_cash_request to df_fees based on the cash_request_id column
df_fees["cohort"] = df_fees["cash_request_id"].map(df_cash_request.set_index("cash_request_id")["cohort"])

print("NaNs cohort in df_fees",df_fees["cohort"].isnull().sum())

df_fees
# Out:
# NaNs id in df_fees 0
# NaNs cash_request_id in df_fees 4
# NaNs cash_request id in df_cash_request 0
# NaNs cohort in df_fees 4
#           id  cash_request_id             type    status  total_amount  \
# 0       6537          14941.0  instant_payment  rejected           5.0
# 1       6961          11714.0         incident  accepted           5.0
# 2      16296          23371.0  instant_payment  accepted           5.0
# 3      20775          26772.0  instant_payment  accepted           5.0
# 4      11242          19350.0  instant_payment  accepted           5.0
# ...      ...              ...              ...       ...           ...
# 21056  12372          20262.0  instant_payment  rejected           5.0
# 21057  20768          26764.0  instant_payment  rejected           5.0
# 21058  18779          25331.0  instant_payment  rejected           5.0
# 21059  16542          23628.0  instant_payment  rejected           5.0
# 21060  13301          20982.0  instant_payment  accepted           5.0
#
#                                    reason                     created_at  \
# 0      Instant Payment Cash Request 14941   2020-09-07 10:47:27.42315+00
# 1                   rejected direct debit  2020-09-09 20:51:17.998653+00
# 2      Instant Payment Cash Request 23371  2020-10-23 10:10:58.352972+00
# 3      Instant Payment Cash Request 26772  2020-10-31 15:46:53.643958+00
# 4      Instant Payment Cash Request 19350  2020-10-06 08:20:17.170432+00
# ...                                   ...                            ...
# 21056  Instant Payment Cash Request 20262  2020-10-10 06:42:22.822743+00
# 21057  Instant Payment Cash Request 26764  2020-10-31 15:24:18.680694+00
# 21058  Instant Payment Cash Request 25331  2020-10-27 17:28:51.749177+00
# 21059  Instant Payment Cash Request 23628  2020-10-23 16:27:52.047457+00
# 21060  Instant Payment Cash Request 20982  2020-10-14 07:12:43.958192+00
#
#                           updated_at                        paid_at  \
# 0      2020-10-13 14:25:09.396112+00   2020-12-17 14:50:07.47011+00
# 1      2020-10-13 14:25:15.537063+00   2020-12-08 17:13:10.45908+00
# 2      2020-10-23 10:10:58.352994+00   2020-11-04 19:34:37.43291+00
# 3      2020-10-31 15:46:53.643982+00  2020-11-19 05:09:22.500223+00
# 4      2020-10-13 14:25:03.267983+00  2020-11-02 14:45:20.355598+00
# ...                              ...                            ...
# 21056   2020-10-13 14:25:04.18049+00  2020-11-17 05:14:00.080854+00
# 21057  2020-10-31 15:24:18.680715+00  2020-12-16 07:10:54.697639+00
# 21058    2020-10-27 17:28:51.7492+00  2020-11-18 04:35:42.915511+00
# 21059  2020-10-23 16:27:52.047486+00  2020-12-18 05:18:01.465317+00
# 21060  2020-10-14 07:12:43.958219+00   2021-02-12 13:02:46.95022+00
#
#       charge_moment  postpone_fees  is_incident     cohort
# 0             after          False        False  Cohorts-2
# 1             after          False         True  Cohorts-2
# 2             after          False        False  Cohorts-2
# 3             after          False        False  Cohorts-2
# 4             after          False        False  Cohorts-2
# ...             ...            ...          ...        ...
# 21056         after          False        False  Cohorts-2
# 21057         after          False        False  Cohorts-2
# 21058         after          False        False  Cohorts-2
# 21059         after          False        False  Cohorts-2
# 21060         after          False        False  Cohorts-2
#
# [21061 rows x 13 columns]

# %%
# find rows with NaNs
nan_rows = df_fees[df_fees["cohort"].isna()]
nan_rows
# Out:
#          id  cash_request_id             type     status  total_amount  \
# 1911   2990              NaN  instant_payment  cancelled           5.0
# 1960   3124              NaN  instant_payment  cancelled           5.0
# 4605   5185              NaN  instant_payment  cancelled           5.0
# 11870  3590              NaN  instant_payment  cancelled           5.0
#
#                                    reason                     created_at  \
# 1911   Instant Payment Cash Request 11164  2020-08-06 22:42:34.525373+00
# 1960   Instant Payment Cash Request 11444  2020-08-08 06:33:06.244651+00
# 4605   Instant Payment Cash Request 11788  2020-08-26 09:39:37.362933+00
# 11870  Instant Payment Cash Request 12212  2020-08-12 14:20:06.657075+00
#
#                           updated_at paid_at charge_moment  postpone_fees  \
# 1911   2020-11-04 16:01:17.296048+00     NaN         after          False
# 1960   2020-11-04 16:01:08.332978+00     NaN         after          False
# 4605   2020-11-04 16:01:36.492576+00     NaN         after          False
# 11870  2020-11-04 16:01:53.106416+00     NaN         after          False
#
#        is_incident cohort
# 1911         False    NaN
# 1960         False    NaN
# 4605         False    NaN
# 11870        False    NaN

# %%
# Sum total amount for "cohorts-1"
cohort1_total = df_fees[df_fees["cohort"] == "Cohorts-1"]["total_amount"].sum()

# Sum total amount for "cohorts-2"
cohort2_total = df_fees[df_fees["cohort"] == "Cohorts-2"]["total_amount"].sum()

print(f"Total Amount for Cohorts-1: {cohort1_total}")
print(f"Total Amount for Cohorts-2: {cohort2_total}")
# Out:
# Total Amount for Cohorts-1: 1290.0
# Total Amount for Cohorts-2: 104000.0
